# %%
import pandas as pd
import numpy as np
import pandas as pd
import warnings

# Mengabaikan peringatan SettingWithCopyWarning
warnings.simplefilter(action='ignore', category=pd.errors.PerformanceWarning)

# %%
df_jenisSampah = pd.read_excel("Data/Data_Komposisi_Jenis_Sampah_SIPSN_KLHK_Jawa Tengah.xlsx", header=1)
df_komposisiSampah = pd.read_excel("Data/Data_Komposisi_Sumber_Sampah_SIPSN_KLHK_Jawa Tengah.xlsx", header=1)
df_timbunanSampah = pd.read_excel("Data/Data_Timbulan_Sampah_SIPSN_KLHK_Jawa Tengah.xlsx", header=1)

# %%
df_jenisSampah.head(100)
# Out:
#     Tahun     Provinsi    Kabupaten/Kota  Sisa Makanan (%)  Kayu-Ranting (%)  \
# 0    2023  Jawa Tengah      Kab. Cilacap             57.67              1.71
# 1    2023  Jawa Tengah     Kab. Banyumas             36.00              6.00
# 2    2023  Jawa Tengah    Kab. Purworejo             15.20             52.60
# 3    2023  Jawa Tengah     Kab. Wonosobo             45.00              7.00
# 4    2023  Jawa Tengah     Kab. Magelang             45.41              6.71
# 5    2023  Jawa Tengah     Kab. Boyolali               NaN               NaN
# 6    2023  Jawa Tengah    Kab. Sukoharjo             60.80              1.88
# 7    2023  Jawa Tengah       Kab. Sragen             74.30              0.80
# 8    2023  Jawa Tengah     Kab. Grobogan               NaN               NaN
# 9    2023  Jawa Tengah        Kab. Blora             20.00             40.00
# 10   2023  Jawa Tengah       Kab. Jepara             53.31              0.96
# ...

# %%
df_jenisSampah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Tahun              60 non-null     int64
#  1   Provinsi           60 non-null     object
#  2   Kabupaten/Kota     60 non-null     object
#  3   Sisa Makanan (%)   41 non-null     float64
#  4   Kayu-Ranting (%)   37 non-null     float64
#  5   Kertas-Karton (%)  42 non-null     float64
#  6   Plastik(%)         42 non-null     float64
#  7   Logam(%)           42 non-null     float64
#  8   Kain(%)            41 non-null     float64
#  9   Karet- Kulit (%)   37 non-null     float64
#  10  Kaca(%)            42 non-null     float64
#  11  Lainnya(%)         40 non-null     float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 5.8+ KB

# %%
df_jenisSampah.describe().T
# Out:
#                    count         mean        std      min        25%      50%  \
# Tahun               60.0  2021.733333   1.117908  2020.00  2021.0000  2022.00
# Sisa Makanan (%)    41.0    42.181220  19.396565     3.00    28.3200    40.00
# Kayu-Ranting (%)    37.0    13.881351  17.569243     0.80     1.8000     6.00
# Kertas-Karton (%)   42.0    10.763333   5.411076     2.00     7.1100    10.00
# Plastik(%)          42.0    20.190476   7.910080     5.54    15.2500    18.40
# Logam(%)            42.0     3.038810   3.395356     0.20     0.8325     1.24
# Kain(%)             41.0     2.621707   1.723064     0.18     1.8000     2.00
# Karet- Kulit (%)    37.0     1.541351   1.610468     0.10     0.6800     1.00
# Kaca(%)             42.0     2.389048   2.171634     0.38     1.1775     1.79
# Lainnya(%)          40.0     5.993750   4.780147     0.30     2.8475     5.00
#
#                          75%      max
# Tahun              2023.0000  2023.00
# ...

# %%
df_komposisiSampah.head(100)
# Out:
#     Tahun     Provinsi    Kabupaten/Kota  Rumah Tangga(ton)  Perkantoran(ton)  \
# 0    2023  Jawa Tengah      Kab. Cilacap                NaN               NaN
# 1    2023  Jawa Tengah     Kab. Banyumas           99999.99          16242.00
# 2    2023  Jawa Tengah    Kab. Purworejo              22.20              0.01
# 3    2023  Jawa Tengah     Kab. Wonosobo              50.00              5.00
# 4    2023  Jawa Tengah     Kab. Magelang                NaN               NaN
# 5    2023  Jawa Tengah     Kab. Boyolali                NaN               NaN
# 6    2023  Jawa Tengah    Kab. Sukoharjo             174.38             32.70
# 7    2023  Jawa Tengah       Kab. Sragen             187.36             40.01
# 8    2023  Jawa Tengah     Kab. Grobogan                NaN               NaN
# 9    2023  Jawa Tengah        Kab. Blora             205.74              5.00
# 10   2023  Jawa Tengah       Kab. Jepara                NaN               NaN
# ...

# %%
df_komposisiSampah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Tahun                  60 non-null     int64
#  1   Provinsi               60 non-null     object
#  2   Kabupaten/Kota         60 non-null     object
#  3   Rumah Tangga(ton)      34 non-null     float64
#  4   Perkantoran(ton)       31 non-null     float64
#  5   Pasar(ton)             33 non-null     float64
#  6   Perniagaan(ton)        29 non-null     float64
#  7   Fasilitas Publik(ton)  31 non-null     float64
#  8   Kawasan(ton)           26 non-null     float64
#  9   Lain(ton)              30 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 4.8+ KB

# %%
df_komposisiSampah.describe().T
# Out:
#                        count          mean           std      min        25%  \
# Tahun                   60.0   2021.733333      1.117908  2020.00  2021.0000
# Rumah Tangga(ton)       34.0  13763.524412  33506.140024    16.00    52.2800
# Perkantoran(ton)        31.0   1714.729677   5325.187537     0.01     2.8750
# Pasar(ton)              33.0   4442.881515  13672.833765     0.34    20.0000
# Perniagaan(ton)         29.0   5601.524828  17972.970312     0.02     3.0000
# Fasilitas Publik(ton)   31.0   2363.153226   7484.947597     0.58     7.0000
# Kawasan(ton)            26.0   1518.898846   4193.348829     1.00     4.6000
# Lain(ton)               30.0   1023.103667   3008.627613     0.75     3.8125
#
#                             50%        75%       max
# Tahun                  2022.000  2023.0000   2023.00
# Rumah Tangga(ton)       139.275   282.3050  99999.99
# Perkantoran(ton)          5.200    29.0100  20353.46
# Pasar(ton)               50.860   148.0000  63604.58
# ...

# %%
df_timbunanSampah.head(100)
# Out:
#     Tahun     Provinsi    Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 0    2023  Jawa Tengah      Kab. Cilacap                       473.35
# 1    2023  Jawa Tengah     Kab. Banyumas                       541.80
# 2    2023  Jawa Tengah    Kab. Purworejo                       321.73
# 3    2023  Jawa Tengah     Kab. Wonosobo                       371.97
# 4    2023  Jawa Tengah     Kab. Magelang                       615.28
# 5    2023  Jawa Tengah     Kab. Boyolali                       295.73
# 6    2023  Jawa Tengah    Kab. Sukoharjo                       363.29
# 7    2023  Jawa Tengah       Kab. Sragen                       595.35
# 8    2023  Jawa Tengah     Kab. Grobogan                       855.65
# 9    2023  Jawa Tengah        Kab. Blora                       387.49
# 10   2023  Jawa Tengah       Kab. Jepara                       408.81
# 11   2023  Jawa Tengah     Kab. Semarang                       533.16
# ...

# %%
df_timbunanSampah.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Tahun                         60 non-null     int64
#  1   Provinsi                      60 non-null     object
#  2   Kabupaten/Kota                60 non-null     object
#  3   Timbulan Sampah Harian(ton)   60 non-null     float64
#  4   Timbulan Sampah Tahunan(ton)  60 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df_timbunanSampah.describe().T
# Out:
#                               count           mean           std       min  \
# Tahun                          60.0    2021.733333      1.117908   2020.00
# Timbulan Sampah Harian(ton)    60.0     489.447500    265.173871     80.55
# Timbulan Sampah Tahunan(ton)   60.0  178648.192667  96788.225833  29400.33
#
#                                       25%         50%          75%        max
# Tahun                           2021.0000    2022.000    2023.0000    2023.00
# Timbulan Sampah Harian(ton)      320.6400     408.305     596.5875    1276.74
# Timbulan Sampah Tahunan(ton)  117034.7675  149030.575  217753.4350  466010.79

# %%
df_jenisSampah.columns
# Out:
# Index(['Tahun', 'Provinsi', 'Kabupaten/Kota', 'Sisa Makanan (%)',
#        'Kayu-Ranting (%)', 'Kertas-Karton (%)', 'Plastik(%)', 'Logam(%)',
#        'Kain(%)', 'Karet- Kulit (%)', 'Kaca(%)', 'Lainnya(%)'],
#       dtype='object')

# %%
df_komposisiSampah.columns
# Out:
# Index(['Tahun', 'Provinsi', 'Kabupaten/Kota', 'Rumah Tangga(ton)',
#        'Perkantoran(ton)', 'Pasar(ton)', 'Perniagaan(ton)',
#        'Fasilitas Publik(ton)', 'Kawasan(ton)', 'Lain(ton)'],
#       dtype='object')

# %%
df_timbunanSampah.columns
# Out:
# Index(['Tahun', 'Provinsi', 'Kabupaten/Kota', 'Timbulan Sampah Harian(ton)',
#        'Timbulan Sampah Tahunan(ton)'],
#       dtype='object')

# %%
df = df_timbunanSampah
df.head()
# Out:
#    Tahun     Provinsi  Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 0   2023  Jawa Tengah    Kab. Cilacap                       473.35
# 1   2023  Jawa Tengah   Kab. Banyumas                       541.80
# 2   2023  Jawa Tengah  Kab. Purworejo                       321.73
# 3   2023  Jawa Tengah   Kab. Wonosobo                       371.97
# 4   2023  Jawa Tengah   Kab. Magelang                       615.28
#
#    Timbulan Sampah Tahunan(ton)
# 0                     172771.48
# 1                     197758.42
# 2                     117432.91
# 3                     135767.88
# 4                     224575.92

# %%
cols1 = ['Rumah Tangga(ton)',
       'Perkantoran(ton)', 'Pasar(ton)', 'Perniagaan(ton)',
       'Fasilitas Publik(ton)', 'Kawasan(ton)', 'Lain(ton)']

for col in cols1:
    df[col] = df_komposisiSampah[col]

# %%
df.head()
# Out:
#    Tahun     Provinsi  Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 0   2023  Jawa Tengah    Kab. Cilacap                       473.35
# 1   2023  Jawa Tengah   Kab. Banyumas                       541.80
# 2   2023  Jawa Tengah  Kab. Purworejo                       321.73
# 3   2023  Jawa Tengah   Kab. Wonosobo                       371.97
# 4   2023  Jawa Tengah   Kab. Magelang                       615.28
#
#    Timbulan Sampah Tahunan(ton)  Rumah Tangga(ton)  Perkantoran(ton)  \
# 0                     172771.48                NaN               NaN
# 1                     197758.42           99999.99          16242.00
# 2                     117432.91              22.20              0.01
# 3                     135767.88              50.00              5.00
# 4                     224575.92                NaN               NaN
#
#    Pasar(ton)  Perniagaan(ton)  Fasilitas Publik(ton)  Kawasan(ton)  Lain(ton)
# ...

# %%
cols2 = ['Sisa Makanan (%)',
       'Kayu-Ranting (%)', 'Kertas-Karton (%)', 'Plastik(%)', 'Logam(%)',
       'Kain(%)', 'Karet- Kulit (%)', 'Kaca(%)', 'Lainnya(%)']

for col in cols2:
    df[col] = df_jenisSampah[col]

# %%
df.head(100)
# Out:
#     Tahun     Provinsi    Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 0    2023  Jawa Tengah      Kab. Cilacap                       473.35
# 1    2023  Jawa Tengah     Kab. Banyumas                       541.80
# 2    2023  Jawa Tengah    Kab. Purworejo                       321.73
# 3    2023  Jawa Tengah     Kab. Wonosobo                       371.97
# 4    2023  Jawa Tengah     Kab. Magelang                       615.28
# 5    2023  Jawa Tengah     Kab. Boyolali                       295.73
# 6    2023  Jawa Tengah    Kab. Sukoharjo                       363.29
# 7    2023  Jawa Tengah       Kab. Sragen                       595.35
# 8    2023  Jawa Tengah     Kab. Grobogan                       855.65
# 9    2023  Jawa Tengah        Kab. Blora                       387.49
# 10   2023  Jawa Tengah       Kab. Jepara                       408.81
# 11   2023  Jawa Tengah     Kab. Semarang                       533.16
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Tahun                         60 non-null     int64
#  1   Provinsi                      60 non-null     object
#  2   Kabupaten/Kota                60 non-null     object
#  3   Timbulan Sampah Harian(ton)   60 non-null     float64
#  4   Timbulan Sampah Tahunan(ton)  60 non-null     float64
#  5   Rumah Tangga(ton)             34 non-null     float64
#  6   Perkantoran(ton)              31 non-null     float64
#  7   Pasar(ton)                    33 non-null     float64
#  8   Perniagaan(ton)               29 non-null     float64
#  9   Fasilitas Publik(ton)         31 non-null     float64
#  10  Kawasan(ton)                  26 non-null     float64
#  11  Lain(ton)                     30 non-null     float64
# ...

# %%
df.dropna(subset=cols1, how="all", axis=0, inplace=True)
df.head()
# Out:
#    Tahun     Provinsi  Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 1   2023  Jawa Tengah   Kab. Banyumas                       541.80
# 2   2023  Jawa Tengah  Kab. Purworejo                       321.73
# 3   2023  Jawa Tengah   Kab. Wonosobo                       371.97
# 6   2023  Jawa Tengah  Kab. Sukoharjo                       363.29
# 7   2023  Jawa Tengah     Kab. Sragen                       595.35
#
#    Timbulan Sampah Tahunan(ton)  Rumah Tangga(ton)  Perkantoran(ton)  \
# 1                     197758.42           99999.99          16242.00
# 2                     117432.91              22.20              0.01
# 3                     135767.88              50.00              5.00
# 6                     132601.14             174.38             32.70
# 7                     217301.22             187.36             40.01
#
#    Pasar(ton)  Perniagaan(ton)  Fasilitas Publik(ton)  ...  Lain(ton)  \
# 1    35733.00         68218.00               19491.00  ...    9747.00
# ...

# %%
df.dropna(subset=cols2, how="all", axis=0, inplace=True)
df.head()
# Out:
#    Tahun     Provinsi  Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 1   2023  Jawa Tengah   Kab. Banyumas                       541.80
# 2   2023  Jawa Tengah  Kab. Purworejo                       321.73
# 3   2023  Jawa Tengah   Kab. Wonosobo                       371.97
# 6   2023  Jawa Tengah  Kab. Sukoharjo                       363.29
# 7   2023  Jawa Tengah     Kab. Sragen                       595.35
#
#    Timbulan Sampah Tahunan(ton)  Rumah Tangga(ton)  Perkantoran(ton)  \
# 1                     197758.42           99999.99          16242.00
# 2                     117432.91              22.20              0.01
# 3                     135767.88              50.00              5.00
# 6                     132601.14             174.38             32.70
# 7                     217301.22             187.36             40.01
#
#    Pasar(ton)  Perniagaan(ton)  Fasilitas Publik(ton)  ...  Lain(ton)  \
# 1    35733.00         68218.00               19491.00  ...    9747.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 1 to 59
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Tahun                         35 non-null     int64
#  1   Provinsi                      35 non-null     object
#  2   Kabupaten/Kota                35 non-null     object
#  3   Timbulan Sampah Harian(ton)   35 non-null     float64
#  4   Timbulan Sampah Tahunan(ton)  35 non-null     float64
#  5   Rumah Tangga(ton)             34 non-null     float64
#  6   Perkantoran(ton)              31 non-null     float64
#  7   Pasar(ton)                    33 non-null     float64
#  8   Perniagaan(ton)               29 non-null     float64
#  9   Fasilitas Publik(ton)         31 non-null     float64
#  10  Kawasan(ton)                  26 non-null     float64
#  11  Lain(ton)                     30 non-null     float64
# ...

# %%
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
#    Tahun     Provinsi  Kabupaten/Kota  Timbulan Sampah Harian(ton)  \
# 0   2023  Jawa Tengah   Kab. Banyumas                       541.80
# 1   2023  Jawa Tengah  Kab. Purworejo                       321.73
# 2   2023  Jawa Tengah   Kab. Wonosobo                       371.97
# 3   2023  Jawa Tengah  Kab. Sukoharjo                       363.29
# 4   2023  Jawa Tengah     Kab. Sragen                       595.35
#
#    Timbulan Sampah Tahunan(ton)  Rumah Tangga(ton)  Perkantoran(ton)  \
# 0                     197758.42           99999.99          16242.00
# 1                     117432.91              22.20              0.01
# 2                     135767.88              50.00              5.00
# 3                     132601.14             174.38             32.70
# 4                     217301.22             187.36             40.01
#
#    Pasar(ton)  Perniagaan(ton)  Fasilitas Publik(ton)  ...  Lain(ton)  \
# 0    35733.00         68218.00               19491.00  ...    9747.00
# ...

# %%
df[cols1]
# Out:
#     Rumah Tangga(ton)  Perkantoran(ton)  Pasar(ton)  Perniagaan(ton)  \
# 0            99999.99          16242.00    35733.00         68218.00
# 1               22.20              0.01       27.60              NaN
# 2               50.00              5.00       20.00            10.00
# 3              174.38             32.70       50.86            43.59
# 4              187.36             40.01      148.00            49.89
# 5              205.74              5.00      100.00            30.00
# 6              144.00               NaN       52.00              NaN
# 7              275.12             12.79       12.11            10.42
# 8               25.00              3.00       45.00             2.00
# 9                 NaN               NaN         NaN              NaN
# 10              72.00              0.50        2.60             8.00
# 11           99999.99          16242.00    35733.00         68218.00
# 12              37.70              5.20       14.00             7.30
# ...

# %%
df[cols2]
# Out:
#     Sisa Makanan (%)  Kayu-Ranting (%)  Kertas-Karton (%)  Plastik(%)  \
# 0              36.00              6.00               6.00       30.00
# 1              15.20             52.60               2.30       14.40
# 2              45.00              7.00               9.00       15.00
# 3              60.80              1.88               9.81       17.03
# 4              74.30              0.80               8.90       11.20
# 5              20.00             40.00              10.00       17.00
# 6              61.56             11.58               4.25       18.53
# 7              31.33             17.62               6.68       18.27
# 8               5.00             50.00               5.00       25.00
# 9                NaN               NaN              24.60        5.54
# 10             60.80               NaN              10.20       17.20
# 11             36.00              6.00               6.00       30.00
# ...

# %%
df_coba = df[cols2]
df_coba
# Out:
#     Sisa Makanan (%)  Kayu-Ranting (%)  Kertas-Karton (%)  Plastik(%)  \
# 0              36.00              6.00               6.00       30.00
# 1              15.20             52.60               2.30       14.40
# 2              45.00              7.00               9.00       15.00
# 3              60.80              1.88               9.81       17.03
# 4              74.30              0.80               8.90       11.20
# 5              20.00             40.00              10.00       17.00
# 6              61.56             11.58               4.25       18.53
# 7              31.33             17.62               6.68       18.27
# 8               5.00             50.00               5.00       25.00
# 9                NaN               NaN              24.60        5.54
# 10             60.80               NaN              10.20       17.20
# 11             36.00              6.00               6.00       30.00
# ...

# %%
"""#cek kolom yang missing
misscol = []
for col in cols2:
    if pd.isnull(df_coba.loc[0, col]) == True:
        misscol.append(col)
sisacol = list(set(cols2) - set(misscol))
# jumlah
if len(misscol) == 1:
    total = df_coba.loc[0, sisacol].tolist()
    total = sum(total)
    total = 100-total
    df_coba.loc[0, misscol] = total
elif len(misscol)>1:
    total = df_coba.loc[0,sisacol].tolist()
    total = sum(total)
    total = (100-total)/len(misscol)
    for col in misscol:
        df_coba.loc[0, col] = total"""
# Out:
# '#cek kolom yang missing\nmisscol = []\nfor col in cols2:\n    if pd.isnull(df_coba.loc[0, col]) == True:\n        misscol.append(col)\nsisacol = list(set(cols2) - set(misscol))\n# jumlah\nif len(misscol) == 1:\n    total = df_coba.loc[0, sisacol].tolist()\n    total = sum(total)\n    total = 100-total\n    df_coba.loc[0, misscol] = total\nelif len(misscol)>1:\n    total = df_coba.loc[0,sisacol].tolist()\n    total = sum(total)\n    total = (100-total)/len(misscol)\n    for col in misscol:\n        df_coba.loc[0, col] = total'

# %%
misscol = []
for col in cols2:
    if pd.isnull(df_coba.loc[0, col]) == True:
        misscol.append(col)
sisacol = list(set(cols2) - set(misscol))

print("misscol", misscol)
print("sisacol", sisacol)

listval = total = df_coba.loc[0, sisacol].tolist()
print("lisval :", listval)
total = sum(listval)
print("Total1 :", total)
total = 100-total
print("Total1 :", total)
#df_coba.loc[0, misscol] = total
# Out:
# misscol ['Lainnya(%)']
# sisacol ['Logam(%)', 'Kertas-Karton (%)', 'Kain(%)', 'Sisa Makanan (%)', 'Karet- Kulit (%)', 'Kayu-Ranting (%)', 'Kaca(%)', 'Plastik(%)']
# lisval : [9.0, 6.0, 5.0, 36.0, 3.0, 6.0, 5.0, 30.0]
# Total1 : 100.0
# Total1 : 0.0

# %%
len(df_coba.index)
# Out:
# 35

# %%
for i in range(len(df_coba.index)):
    misscol = []
    for col in cols2:
        if pd.isnull(df_coba.loc[i, col]) == True:
            misscol.append(col)
    sisacol = list(set(cols2) - set(misscol))
    if len(misscol)==1:
        listval = total = df_coba.loc[i, sisacol].tolist()
        total = sum(listval)
        total = 100-total
        df_coba.loc[i, misscol] = total
    elif len(misscol)>1:
        total = df_coba.loc[i,sisacol].tolist()
        total = sum(total)
        total = (100-total)/len(misscol)
        total = round(total,2)
        for col in misscol:
            df_coba.loc[i, misscol] = total
# Out:
# /var/folders/nd/s6snn9l53zg5sthh_ttcvdpr0000gn/T/ipykernel_73396/476055278.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_coba.loc[i, misscol] = total
# /var/folders/nd/s6snn9l53zg5sthh_ttcvdpr0000gn/T/ipykernel_73396/476055278.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_coba.loc[i, misscol] = total
# /var/folders/nd/s6snn9l53zg5sthh_ttcvdpr0000gn/T/ipykernel_73396/476055278.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df_coba.head(100)
# Out:
#     Sisa Makanan (%)  Kayu-Ranting (%)  Kertas-Karton (%)  Plastik(%)  \
# 0              36.00              6.00               6.00       30.00
# 1              15.20             52.60               2.30       14.40
# 2              45.00              7.00               9.00       15.00
# 3              60.80              1.88               9.81       17.03
# 4              74.30              0.80               8.90       11.20
# 5              20.00             40.00              10.00       17.00
# 6              61.56             11.58               4.25       18.53
# 7              31.33             17.62               6.68       18.27
# 8               5.00             50.00               5.00       25.00
# 9               5.92              5.92              24.60        5.54
# 10             60.80              0.00              10.20       17.20
# 11             36.00              6.00               6.00       30.00
# ...
